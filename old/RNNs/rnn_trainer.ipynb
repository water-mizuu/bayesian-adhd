# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam, RMSprop, SGD

# %%
df = pd.read_csv("./processed_adhdata.csv")
df['Class'] = LabelEncoder().fit_transform(df['Class'])  # ADHD->1, Control->0

frequency_count = len(df['Frequency'].unique())
window_count = len(df['Window'].unique())
numeric_df = df.drop(['ID', 'Window'], axis=1)

# shape: (windows, freqs, features)
full_ndarray = numeric_df.values.reshape(
    (window_count, frequency_count, numeric_df.shape[1])
)

X = full_ndarray[:, :, 2:]     # drop ID/Class columns
y = full_ndarray[:, 0, 0]      # class label is repeated across freq rows

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# Add channel dimension (N, 1, freq, electrodes)
X_train = X_train[..., np.newaxis]   # (N, freq, electrodes, 1)
X_test  = X_test[...,  np.newaxis]

# Standardize across the entire dataset
scaler = StandardScaler()
X_train_flat = X_train.reshape(-1, X_train.shape[-1])
X_test_flat  = X_test.reshape(-1, X_test.shape[-1])

X_train_scaled = scaler.fit_transform(X_train_flat)
X_test_scaled  = scaler.transform(X_test_flat)

X_train = X_train_scaled.reshape(X_train.shape)
X_test  = X_test_scaled.reshape(X_test.shape)

print("Train shape:", X_train.shape)  # (N, freq, electrodes, 1)
# Out:
# Train shape: (6623, 77, 19, 1)

# %%
class EEGDatasetRNN(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)  # (N, freq, electrodes)
        self.y = torch.tensor(y, dtype=torch.long)
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_ds = EEGDatasetRNN(X_train, y_train)
test_ds  = EEGDatasetRNN(X_test,  y_test)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
test_loader  = DataLoader(test_ds, batch_size=32, shuffle=False)

# %%
class EEG_RNN(nn.Module):
    def __init__(self, input_size, hidden_size=64, num_layers=2,
                 dropout=0.3, num_classes=2):
        super().__init__()
        self.rnn = nn.RNN(input_size=input_size,
                          hidden_size=hidden_size,
                          num_layers=num_layers,
                          batch_first=True,
                          nonlinearity='tanh',   # or 'relu'
                          dropout=dropout if num_layers > 1 else 0.0)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        # x: (batch, seq_len=freq, features=electrodes)
        if x.dim() == 4:
            x = x.squeeze(-1)  # remove singleton last dim if present
        # RNN returns: output, h_n
        out_seq, h_n = self.rnn(x)       # h_n: (num_layers, batch, hidden)
        last_hidden = h_n[-1]             # last layer hidden state
        return self.fc(last_hidden)       # raw logits
    def fit(self, train_loader, val_loader, epochs,
            criterion, optimizer, device="cpu", patience=30):
        best_val_loss = float('inf')
        no_improve = 0
        best_state = None

        train_losses, val_losses = [], []
        train_accs,  val_accs  = [], []

        for epoch in range(epochs):
            # ---- Train ----
            self.train()
            train_loss, train_correct = 0.0, 0
            for xb, yb in train_loader:
                xb, yb = xb.to(device), yb.to(device)
                optimizer.zero_grad()
                out = self(xb)
                loss = criterion(out, yb)
                loss.backward()
                optimizer.step()
                train_loss += loss.item() * xb.size(0)
                train_correct += (out.argmax(1) == yb).sum().item()

            train_loss /= len(train_loader.dataset)
            train_acc  = train_correct / len(train_loader.dataset)
            train_losses.append(train_loss)
            train_accs.append(train_acc)

            # ---- Validate ----
            self.eval()
            val_loss, val_correct = 0.0, 0
            with torch.no_grad():
                for xb, yb in val_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    out = self(xb)
                    loss = criterion(out, yb)
                    val_loss += loss.item() * xb.size(0)
                    val_correct += (out.argmax(1) == yb).sum().item()

            val_loss /= len(val_loader.dataset)
            val_acc  = val_correct / len(val_loader.dataset)
            val_losses.append(val_loss)
            val_accs.append(val_acc)

            print(f"Epoch {epoch+1:03d} | "
                  f"Train Loss: {train_loss:.4f} Acc: {train_acc:.4f} | "
                  f"Val Loss: {val_loss:.4f} Acc: {val_acc:.4f}")

            if val_loss - train_loss > 0.25:
                print("Overfitting detected.")
                break
            
            # Early stopping
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_state = self.state_dict()
                no_improve = 0
            else:
                no_improve += 1
                if no_improve >= patience:
                    print("Early stopping triggered.")
                    break

        if best_state:
            self.load_state_dict(best_state)

        return {
            "train_losses": np.array(train_losses),
            "val_losses":   np.array(val_losses),
            "train_accs":   np.array(train_accs),
            "val_accs":     np.array(val_accs)
        }

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = EEG_RNN(input_size=X_train.shape[2],
                 hidden_size=64,
                 num_layers=2,
                 dropout=0.3).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr=5e-4)

history = model.fit(train_loader, test_loader,
                    epochs=200,
                    criterion=criterion,
                    optimizer=optimizer,
                    device=device,
                    patience=30)
# Out:
# Epoch 001 | Train Loss: 0.6927 Acc: 0.5547 | Val Loss: 0.6882 Acc: 0.5586
# Epoch 002 | Train Loss: 0.6871 Acc: 0.5585 | Val Loss: 0.6911 Acc: 0.5586
# Epoch 003 | Train Loss: 0.6872 Acc: 0.5588 | Val Loss: 0.6878 Acc: 0.5586
# Epoch 004 | Train Loss: 0.6886 Acc: 0.5559 | Val Loss: 0.6898 Acc: 0.5586
# Epoch 005 | Train Loss: 0.6901 Acc: 0.5537 | Val Loss: 0.6896 Acc: 0.5586
# Epoch 006 | Train Loss: 0.6890 Acc: 0.5537 | Val Loss: 0.6863 Acc: 0.5586
# Epoch 007 | Train Loss: 0.6881 Acc: 0.5559 | Val Loss: 0.6865 Acc: 0.5586
# Epoch 008 | Train Loss: 0.6873 Acc: 0.5571 | Val Loss: 0.6865 Acc: 0.5586
# Epoch 009 | Train Loss: 0.6872 Acc: 0.5562 | Val Loss: 0.6873 Acc: 0.5447
# Epoch 010 | Train Loss: 0.6877 Acc: 0.5561 | Val Loss: 0.6862 Acc: 0.5586
# Epoch 011 | Train Loss: 0.6878 Acc: 0.5561 | Val Loss: 0.6877 Acc: 0.5586
# Epoch 012 | Train Loss: 0.6873 Acc: 0.5556 | Val Loss: 0.6868 Acc: 0.5586
# Epoch 013 | Train Loss: 0.6874 Acc: 0.5561 | Val Loss: 0.6886 Acc: 0.5586
# Epoch 014 | Train Loss: 0.6888 Acc: 0.5564 | Val Loss: 0.6869 Acc: 0.5586
# Epoch 015 | Train Loss: 0.6884 Acc: 0.5543 | Val Loss: 0.6868 Acc: 0.5586
# Epoch 016 | Train Loss: 0.6886 Acc: 0.5559 | Val Loss: 0.6881 Acc: 0.5586
# Epoch 017 | Train Loss: 0.6880 Acc: 0.5558 | Val Loss: 0.6869 Acc: 0.5574
# Epoch 018 | Train Loss: 0.6882 Acc: 0.5499 | Val Loss: 0.6873 Acc: 0.5586
# Epoch 019 | Train Loss: 0.6886 Acc: 0.5564 | Val Loss: 0.6840 Acc: 0.5586
# Epoch 020 | Train Loss: 0.6882 Acc: 0.5547 | Val Loss: 0.6845 Acc: 0.5634
# Epoch 021 | Train Loss: 0.6848 Acc: 0.5525 | Val Loss: 0.6842 Acc: 0.5525
# Epoch 022 | Train Loss: 0.6846 Acc: 0.5522 | Val Loss: 0.6780 Acc: 0.5586
# Epoch 023 | Train Loss: 0.6814 Acc: 0.5665 | Val Loss: 0.6772 Acc: 0.5833
# Epoch 024 | Train Loss: 0.6813 Acc: 0.5712 | Val Loss: 0.7109 Acc: 0.4191
# Epoch 025 | Train Loss: 0.6755 Acc: 0.5830 | Val Loss: 0.6741 Acc: 0.5990
# Epoch 026 | Train Loss: 0.6727 Acc: 0.5970 | Val Loss: 0.6627 Acc: 0.6075
# Epoch 027 | Train Loss: 0.6643 Acc: 0.6118 | Val Loss: 0.6529 Acc: 0.6232
# Epoch 028 | Train Loss: 0.6552 Acc: 0.6249 | Val Loss: 0.6750 Acc: 0.6214
# Epoch 029 | Train Loss: 0.6581 Acc: 0.6239 | Val Loss: 0.6581 Acc: 0.6292
# Epoch 030 | Train Loss: 0.6590 Acc: 0.6228 | Val Loss: 0.6618 Acc: 0.6286
# Epoch 031 | Train Loss: 0.6580 Acc: 0.6228 | Val Loss: 0.7198 Acc: 0.4475
# Epoch 032 | Train Loss: 0.6624 Acc: 0.6130 | Val Loss: 0.6469 Acc: 0.6473
# Epoch 033 | Train Loss: 0.6565 Acc: 0.6243 | Val Loss: 0.6537 Acc: 0.6455
# Epoch 034 | Train Loss: 0.6534 Acc: 0.6296 | Val Loss: 0.6562 Acc: 0.6377
# Epoch 035 | Train Loss: 0.6469 Acc: 0.6511 | Val Loss: 0.6515 Acc: 0.6304
# Epoch 036 | Train Loss: 0.6511 Acc: 0.6369 | Val Loss: 0.6578 Acc: 0.6395
# Epoch 037 | Train Loss: 0.6466 Acc: 0.6536 | Val Loss: 0.6554 Acc: 0.6413
# Epoch 038 | Train Loss: 0.6489 Acc: 0.6529 | Val Loss: 0.6501 Acc: 0.6413
# Epoch 039 | Train Loss: 0.6483 Acc: 0.6500 | Val Loss: 0.6629 Acc: 0.6262
# Epoch 040 | Train Loss: 0.6538 Acc: 0.6400 | Val Loss: 0.6619 Acc: 0.6238
# Epoch 041 | Train Loss: 0.6521 Acc: 0.6416 | Val Loss: 0.6581 Acc: 0.6286
# Epoch 042 | Train Loss: 0.6507 Acc: 0.6417 | Val Loss: 0.6598 Acc: 0.6250
# Epoch 043 | Train Loss: 0.6516 Acc: 0.6299 | Val Loss: 0.6686 Acc: 0.6268
# Epoch 044 | Train Loss: 0.6543 Acc: 0.6221 | Val Loss: 0.6539 Acc: 0.6111
# Epoch 045 | Train Loss: 0.6575 Acc: 0.6123 | Val Loss: 0.6599 Acc: 0.6202
# Epoch 046 | Train Loss: 0.6603 Acc: 0.6117 | Val Loss: 0.6582 Acc: 0.6087
# Epoch 047 | Train Loss: 0.6608 Acc: 0.6014 | Val Loss: 0.6633 Acc: 0.5562
# Epoch 048 | Train Loss: 0.6584 Acc: 0.6177 | Val Loss: 0.6596 Acc: 0.6171
# Epoch 049 | Train Loss: 0.6557 Acc: 0.6257 | Val Loss: 0.6598 Acc: 0.6214
# Epoch 050 | Train Loss: 0.6545 Acc: 0.6301 | Val Loss: 0.6644 Acc: 0.6135
# Epoch 051 | Train Loss: 0.6565 Acc: 0.6269 | Val Loss: 0.6617 Acc: 0.6135
# Epoch 052 | Train Loss: 0.6568 Acc: 0.6130 | Val Loss: 0.6638 Acc: 0.6063
# Epoch 053 | Train Loss: 0.6512 Acc: 0.6050 | Val Loss: 0.6601 Acc: 0.5876
# Epoch 054 | Train Loss: 0.6500 Acc: 0.6076 | Val Loss: 0.6689 Acc: 0.5809
# Epoch 055 | Train Loss: 0.6517 Acc: 0.6032 | Val Loss: 0.6582 Acc: 0.5984
# Epoch 056 | Train Loss: 0.6743 Acc: 0.5668 | Val Loss: 0.6718 Acc: 0.5785
# Epoch 057 | Train Loss: 0.6782 Acc: 0.5644 | Val Loss: 0.7385 Acc: 0.4414
# Epoch 058 | Train Loss: 0.6789 Acc: 0.5735 | Val Loss: 0.6886 Acc: 0.5960
# Epoch 059 | Train Loss: 0.6693 Acc: 0.5931 | Val Loss: 0.6840 Acc: 0.5851
# Epoch 060 | Train Loss: 0.6713 Acc: 0.6023 | Val Loss: 0.6722 Acc: 0.6099
# Epoch 061 | Train Loss: 0.6690 Acc: 0.6050 | Val Loss: 0.6655 Acc: 0.6069
# Epoch 062 | Train Loss: 0.6711 Acc: 0.6029 | Val Loss: 0.6703 Acc: 0.5936
# Early stopping triggered.

# %%
model.eval()
all_preds, all_labels = [], []
with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(device)
        preds = model(xb).argmax(1).cpu().numpy()
        all_preds.append(preds)
        all_labels.append(yb.numpy())

all_preds = np.concatenate(all_preds)
all_labels = np.concatenate(all_labels)

print("\nTest Accuracy:", accuracy_score(all_labels, all_preds))
print(classification_report(all_labels, all_preds))
print(confusion_matrix(all_labels, all_preds))
# Out:
# Test Accuracy: 0.5935990338164251
#               precision    recall  f1-score   support
#
#            0       0.60      0.81      0.69       925
#            1       0.57      0.32      0.41       731
#
#     accuracy                           0.59      1656
#    macro avg       0.59      0.57      0.55      1656
# weighted avg       0.59      0.59      0.57      1656
#
# [[748 177]
#  [496 235]]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history['train_accs'], label='Training Accuracy')
plt.plot(history['val_accs'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history['train_losses'], label='Training Loss')
plt.plot(history['val_losses'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
